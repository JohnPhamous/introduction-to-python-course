# %% [markdown]
# # CS10P - Lecture 1: A Practical Introduction to the Python Programming Language
#
# Python is a programming language that is applicable to anyone independent of their field of study. For computing majors, this class will provide a breadth to the core curriculum showing the applications for Python. For non-computing majors, this class will provide a strong foundation on programming which will allow the student to use software in their respective fields.  This course will cover the basics of programming in Python, and consist of 2 projects: a data visualization website and an email automation tool.
#
# By the end of this course, you will learn how to:
#
# * Use Python as a general purpose programming language
# * Use Python to conduct statistical methods and to create visualizations
# * Use Python to automate sending and receiving emails

# %% [markdown]
# ## Logistics:
#
# * **Instructor:** John Pham
# * **Email:** [jpham035@ucr.edu](mailto:jpham035@ucr.edu)
# * **Lecture Date/Time(s):** Day/Time
# * **Location:** ACM Clubroom (Winston Chung 127)
# * **Office Hours:** By appointment via email

# %% [markdown]
# ## Course Schedule:
#
# | Week | Topics | Required Readings and Resources | Assignments Due |
# |-----:|:--------|:---------------------------------|:----------------:|
# |1| Logistics, Software and Tools, Introduction to Programming Concepts I |
# |2| Introduction to Programming Concepts II, Introduction to Python I |
# |3| Introduction to Python II, Introduction to Markdown |
# |4|
# |5|
# |6|
# |7|
# |8|
# |9|
# |10|

# %% [markdown]
# ## Software and Tools:
#
# * We will be using [Jupyter Notebooks](http://jupyter.org/) which is an interactive Python shell for lecture, assignments, and quizzes. To use the Jupyter Notebook software, you will need to do the following:
#     * Download [anaconda](https://www.anaconda.com/download/) for your respective operating system. **Make sure to download the Python 3.6 version.**
#     * Run the installer you just downloaded
#     ![1.PNG](attachment:1.PNG)
#     ![2.PNG](attachment:2.PNG)
#     ![3.PNG](attachment:3.PNG)
#     * Once installed, you will run a program called **Anaconda Prompt**. This program opens up a Terminal. To run the Jupyter Notebook software, type in `jupyter notebook`
#     ![4.PNG](attachment:4.PNG)
#     * Your browser should open to the URL `localhost:8888`. If it doesn't then open a browser and go to that URL.
#     ![5.PNG](attachment:5.PNG)
